# %%
1 + 1
# Out:
# 2

# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# **My First Markdown Cell**

# %%
a = 1
b = 2
c = 4
d = 8
a, b, c, d
# Out:
# (1, 2, 4, 8)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot([a, b, c, d])
plt.show()

# %% [markdown]
# **I didn't brake that!**

# %%
from PIL import Image
Image.open("images/duggu.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1600x1200 at 0x7F38D20E4A20>

# %% [markdown]
# That's all folks!
